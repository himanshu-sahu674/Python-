# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %matplotlib inline help to print the graph in our jupyter notebook

# %%
df = pd.DataFrame(np.random.randn(1000), index = pd.date_range("2019-06-07", periods = 1000), columns = [ 'Values'])

# %%
df
# Out:
#               Values
# 2019-06-07 -0.930768
# 2019-06-08 -0.055918
# 2019-06-09  1.239122
# 2019-06-10 -0.116212
# 2019-06-11 -0.779736
# ...              ...
# 2022-02-26 -0.447072
# 2022-02-27 -0.025069
# 2022-02-28  0.332670
# 2022-03-01 -0.927538
# 2022-03-02 -0.263470
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Values'] = df['Values'].cumsum()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Values'] = df['Values']+10

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#                Values
# 2019-06-07   9.069232
# 2019-06-08   9.013314
# 2019-06-09  10.252436
# 2019-06-10  10.136224
# 2019-06-11   9.356488

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = iris.drop(['species'],axis =1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('titanic')

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
df1['pclass'].plot(kind = 'bar');

# %%
df1['pclass'].plot(kind = 'line');

# %%
df_1 = pd.DataFrame(np.random.randn(10,4), columns = ['a','b','c','d'])

# %%
df_1.head(10)
# Out:
#           a         b         c         d
# 0 -0.360485  0.682269 -2.153194  0.108970
# 1  0.470828 -0.556185  0.799487 -0.431359
# 2  0.568847 -0.906810 -0.208514  0.609655
# 3 -0.902988  0.275590 -0.181963  0.325717
# 4 -0.292358  0.840945 -0.172415  0.448890
# 5  0.741413 -0.081034 -1.482719  0.533307
# 6  1.753073  0.834643 -1.613247 -0.541120
# 7 -1.015728 -1.045860 -0.845021  2.352690
# 8 -0.781209  0.779732  2.222952  1.037725
# 9 -0.054535 -1.328925  0.451083 -0.414189

# %%
df_1.plot.line()
# Out:
# <AxesSubplot:>

# %%
df_1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_1.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df_1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot.hist()
# x - range(interval)
# y - frequency
# frequency vs range graph
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# way to plot the graphs
iris['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
iris['sepal_length'].plot(kind= 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# histogram showing how many data we have in between a particular range

# %%
iris.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True)
# stacked true = showing overlap dataset also in a graph
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 10)
# bins control the width if less then width is large if high then width is small
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50)
# stacked true showing - smaller one in front and bigger one in back
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = False, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris.hist(color = 'b', alpha = .4, figsize =(20,20));
# alpha is opacity

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# comparative study between two coloumns
iris.plot.scatter(x = 'sepal_length', y = 'sepal_width');

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', color = 'r', figsize = (10,10), s =100);
# s will be used for size of dot

# %% [markdown]
#  ### scatter plot
#  * generating graph bw x,y and the color of the dot will be decided by c range
#  * for example 1 row x = 5.1 y =1.4 (yaha se point locate kiye)
#  * now color of point decidecd by c and c ranges in between 2 to 4 in our data

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', figsize = (5,5), c = 'sepal_width', s = 100);
# generating graph bw x,y and the color of the dot will be decided by c range
# for example 1 row x = 5.1 y =1.4 (yaha se point locate kiye)
# now color of point decidecd by c and c ranges in between 2 to 4 in our data

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.hexbin(x = 'sepal_length', y = 'petal_length', figsize = (5,5), C = 'sepal_width', gridsize = 70);
# 2 changes here -
# 1st we are using hexabin instead of circles 
# c replaced by C and s replaced by gridsize

# %%
data = iris.iloc[0] #first row

# %%
data
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
data = data[0:4] #only taking the numerical data

# %%
data.plot.pie();
# pie plot a graph based on respective percentage

# %%
 iris.head(3).iloc[:,0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
 data1 = iris.head(3).iloc[:,0:4].T

# %%
data1
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
data1.plot.pie(subplots = True, figsize = (20,20));
# plotted the data with coloumnwize percentage basis

# %%
iris.drop(['species'],axis = 1, inplace = True)

# %%
iris.head() #dropped species column
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
pd.plotting.scatter_matrix(iris, figsize= (10,10), color = 'r', alpha = .9)
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
# change the diagonal from hist to kernal density estimation (showing which coloum is normaly distributed) plot
pd.plotting.scatter_matrix(iris,diagonal= 'kde',figsize= (10,10), color = 'r', alpha = .9);

# %%
iris['sepal_length'].plot();

# %%
iris['sepal_length'].plot(style = 'r--', label = 'sepal_lenght', legend = True);
# r is the color here and -- is the pattern of line we are plotting
# label give the label to the line 
# legend will show the label in upper right corner

# %%
iris.plot();

# %%
iris.plot(subplots = True);

# %%
iris.plot(logx = True,logy = True) #LOG LOG PLOT
# Out:
# <AxesSubplot:>

# %%
# SEMI LOG PLOT
iris.plot(logy =True, figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# !pip install plotly
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as  tls
import cufflinks as cf

# %%
print(py.__version__)
print(cf.__version__)
# Out:
# 5.6.0
# 0.17.3

# %%
py.offline.init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
iris.iplot()
# Out:
# <div>                            <div id="bd41d902-2c72-4a69-bcfa-f81708511fd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
# above one with ploty is looking better than plot()
