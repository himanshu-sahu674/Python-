# %%
import pandas as pd

# %%
df = pd.read_csv("D:\data ML\Datasets\ohana-api-master\ohana-api-master\dat_aall_csv_files\sample-csv\locations.csv")
# use single backward slash to read files or use double forward slash
# use (r"D:\\data ML\\Datasets\\ohana-api-master\\ohana-api-master\\data all csv files\\sample-csv\\locations.csv")

# %%
df.head()
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
# 2   3                1                                           NaN
# 3   4                1                                    wheelchair
# 4   5                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
#
# ...

# %%
pwd()  # it will show the location of my current jupyter file stored in my system
# Out:
# 'C:\\Users\\himan\\Downloads\\jupyter files'

# %%
df.head(2)
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
#
#                                        languages   latitude   longitude  \
# 0                               Spanish, Tagalog  37.477227 -122.213221
# 1  Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
#
#                                name  \
# 0   Fair Oaks Adult Activity Center
# 1  Second Career Employment Program
#
#                                           short_desc  \
# 0  A multipurpose senior citizens' center serving...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 17  18                5                cd, restroom, wheelchair          NaN
# 18  19                5              elevator, ramp, wheelchair          NaN
# 19  20                6                                     NaN          NaN
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# 17            NaN  Provides free medical care to those in need. O...
# 18            NaN  Provides free medical and dental care to those...
# 19            NaN                                           no phone
# 20            NaN                              This is a description
# 21  The Test Spot  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                email                                        languages  \
# ...

# %%
df.tail(2)
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# 20            NaN                              This is a description
# 21  The Test Spot  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                email                                        languages  \
# 20               NaN                                              NaN
# 21  info@example.org  Cantonese, Russian, Spanish, Tagalog, Taiwanese
#
#      latitude   longitude                 name  \
# 20  37.529194 -122.287161  Admin Test Location
# 21  37.772640 -122.409915     Example Location
#
#                                            short_desc  \
# 20                        This is a short description
# ...

# %%
# if my data don't have the coloumns name pandas will still read
# the first encounter row as the column names
# now not consider first row as a column name

# %%
df2 = pd.read_csv("D:\data ML\Datasets\ohana-api-master\ohana-api-master\dat_aall_csv_files\sample-csv\locations_without_coloumn_name.csv")

# %%
df2.head()
# Out:
#    1  1.1 disabled_parking, ramp, restroom, wheelchair Unnamed: 3 Unnamed: 4  \
# 0  2    1                                   wheelchair        NaN        NaN
# 1  3    1                                          NaN        NaN        NaN
# 2  4    1                                   wheelchair        NaN        NaN
# 3  5    1                                   wheelchair        NaN        NaN
# 4  6    2                 disabled_parking, wheelchair        NaN        NaN
#
# ...

# %%
# to overcome above issue that will not read the first column as header
df3 = pd.read_csv("D:\data ML\Datasets\ohana-api-master\ohana-api-master\dat_aall_csv_files\sample-csv\locations_without_coloumn_name.csv", header = None, 
                  names = ['a','b','c','d','e','a1','b1','c1','d1','e1','a2','b2','c2','d2','e2'])

# %%
df3.head()   # we have not consider the fisrt row as column + we also given the columns names too
# Out:
#    a  b                                             c    d    e  \
# 0  1  1  disabled_parking, ramp, restroom, wheelchair  NaN  NaN
# 1  2  1                                    wheelchair  NaN  NaN
# 2  3  1                                           NaN  NaN  NaN
# 3  4  1                                    wheelchair  NaN  NaN
# 4  5  1                                    wheelchair  NaN  NaN
#
#                                                   a1   b1  \
# 0  A walk-in center for older adults that provide...  NaN
# 1  Provides training and job placement to eligibl...  NaN
# 2  Offers supportive counseling services to San M...  NaN
# 3  Provides supervised visitation services and a ...  NaN
# 4  Provides fixed 8% short term loans to eligible...  NaN
#
#                                                   c1         d1          e1  \
# 0                                   Spanish, Tagalog  37.477227 -122.213221
# ...

# %%
# skiping the selected rows and comparing 
df.head(10)
# Out:
#    id  organization_id                                      accessibility  \
# 0   1                1       disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                         wheelchair
# 2   3                1                                                NaN
# 3   4                1                                         wheelchair
# 4   5                1                                         wheelchair
# 5   6                2                       disabled_parking, wheelchair
# 6   7                2       ramp, restroom, disabled_parking, wheelchair
# 7   8                2                                                NaN
# 8   9                3                         ramp, restroom, wheelchair
# 9  10                3  elevator, tape_braille, ramp, restroom, disabl...
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# ...

# %%
df4 = pd.read_csv("D:\data ML\Datasets\ohana-api-master\ohana-api-master\dat_aall_csv_files\sample-csv\locations.csv",
                  skiprows =[1,4,6,8])

# %%
df4.head(10) #sucessfully skipped 1,4,6,8 rows from our df
# Out:
#    id  organization_id                                      accessibility  \
# 0   2                1                                         wheelchair
# 1   3                1                                                NaN
# 2   5                1                                         wheelchair
# 3   7                2       ramp, restroom, disabled_parking, wheelchair
# 4   9                3                         ramp, restroom, wheelchair
# 5  10                3  elevator, tape_braille, ramp, restroom, disabl...
# 6  11                3                                               ramp
# 7  12                3         disabled_parking, elevator, ramp, restroom
# 8  13                3                                                NaN
# 9  14                4                                         wheelchair
#
#       admin_emails alternate_name  \
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# ...

# %%
# na_values will make the any value as Nan like here we are making wheelchare as Nan (1,1)
df4 = pd.read_csv("D:\data ML\Datasets\ohana-api-master\ohana-api-master\dat_aall_csv_files\sample-csv\locations.csv",
                  na_values = ['wheelchair'])

# %%
df.head()
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
# 2   3                1                                           NaN
# 3   4                1                                    wheelchair
# 4   5                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
#
# ...

# %%
df4.head()
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                           NaN
# 2   3                1                                           NaN
# 3   4                1                                           NaN
# 4   5                1                                           NaN
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
#
# ...

# %% [markdown]
# # reading the excel files

# %%
ex = pd.read_excel("D:\data ML\Datasets\excel_file\java-read-write-excel-file-using-apache-poi-master\sample-xlsx-file.xlsx")

# %%
ex.head()  #by default pd.read_csv will read the data from very first tab
# Out:
#            Name               Email Date Of Birth     Salary  \
# 0  Rajeev Singh  rajeev@example.com    1992-07-21  1500000.0
# 1      John Doe    john@example.com    1965-01-13  1300000.0
# 2  Jack Sparrow    jack@example.com    1986-12-19  1000000.0
# 3   Steven Cook  steven@example.com    1994-05-04  1200000.0
#
#              Department
# 0  Software Engineering
# 1                 Sales
# 2                    HR
# 3             Marketing

# %%
# for reading the data from another tab
pd.read_excel("D:\data ML\Datasets\excel_file\java-read-write-excel-file-using-apache-poi-master\sample-xlsx-file.xlsx",
             sheet_name = "Department")
# Out:
#                    Name     Budget
# 0  Software Engineering  5000000.0
# 1                    HR  2000000.0
# 2                 Sales  4000000.0
# 3             Marketing  3000000.0

# %%
# reading the data from html pages
df5 = pd.read_html("https://www.basketball-reference.com/leaders/orb_top_10.html")

# %%
df5
# Out:
# [     Season   Lg                 1st                                2nd  \
#  0   2021-22  NBA      S. Adams (349)                  M. Robinson (295)
#  1   2020-21  NBA     C. Capela (297)                   E. Freedom (284)
#  2   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
#  3   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
#  4   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
#  5   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
#  6   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
#  7   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
#  8   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
#  9   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
#  10  2011-12  NBA    D. Cousins (265)                      J. Noah (242)
#  11  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
# ...

# %%
type(df5)
# Out:
# list

# %%
len(df5)  #this link is storing only 1 data in list format that is only one table it is having
# Out:
# 1

# %%
df6 = df5[0]   # to acces the table

# %%
df6
# Out:
#      Season   Lg                 1st                                2nd  \
# 0   2021-22  NBA      S. Adams (349)                  M. Robinson (295)
# 1   2020-21  NBA     C. Capela (297)                   E. Freedom (284)
# 2   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
# 3   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
# 4   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
# 5   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
# 6   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
# 7   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
# 8   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
# 9   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
# 10  2011-12  NBA    D. Cousins (265)                      J. Noah (242)
# 11  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
# ...

# %%
type(df6)
# Out:
# pandas.core.frame.DataFrame

# %%
df6.shape
# Out:
# (58, 12)

# %%
xx = pd.read_html("https://www.espncricinfo.com/series/commonwealth-games-women-s-cricket-competition-2022-1289194/india-women-vs-pakistan-women-5th-match-group-a-1289263/full-scorecard")

# %%
len(xx)   #there are total 10 data tables with indexing 0-9
# Out:
# 10

# %%
xx[0].head()
# Out:
#              BATTING                Unnamed: 1    R    B    M   4s   6s  \
# 0      Muneeba Ali †                c & b Rana   32   30    -    3    1
# 1                NaN                       NaN  NaN  NaN  NaN  NaN  NaN
# 2         Iram Javed  c †Bhatia b Meghna Singh    0    3    -    0    0
# 3                NaN                       NaN  NaN  NaN  NaN  NaN  NaN
# 4  Bismah Maroof (c)                lbw b Rana   17   19    -    0    0
#
#        SR Unnamed: 8  Unnamed: 9
# 0  106.66        NaN         NaN
# 1     NaN        NaN         NaN
# 2    0.00        NaN         NaN
# 3     NaN        NaN         NaN
# 4   89.47        NaN         NaN

# %%
xx[1].tail()
# Out:
#                                               BOWLING  \
# 6   8.3 to Bismah Maroof, tried to sweep but misse...
# 7                                         Radha Yadav
# 8   17.2 to Diana Baig, We don't even need to go u...
# 9                                       Shafali Verma
# 10  16.6 to Fatima Sana, soft signal out! What's h...
#
#                                                     O  \
# 6   8.3 to Bismah Maroof, tried to sweep but misse...
# 7                                                   3
# 8   17.2 to Diana Baig, We don't even need to go u...
# 9                                                   2
# 10  16.6 to Fatima Sana, soft signal out! What's h...
#
#                                                     M  \
# 6   8.3 to Bismah Maroof, tried to sweep but misse...
# 7                                                   0
# 8   17.2 to Diana Baig, We don't even need to go u...
# 9                                                   0
# ...

# %%
xx[0].shape
# Out:
# (24, 10)

# %%
xx[1].shape
# Out:
# (11, 11)

# %%
# sometime the raw data are tab seperated so we read data by pd.read_csv("file_location", sep = '\t')

# %%
xx[0].dtypes
# Out:
# BATTING        object
# Unnamed: 1     object
# R              object
# B              object
# M              object
# 4s             object
# 6s             object
# SR             object
# Unnamed: 8     object
# Unnamed: 9    float64
# dtype: object

# %%
xx[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BATTING     14 non-null     object
#  1   Unnamed: 1  14 non-null     object
#  2   R           14 non-null     object
#  3   B           12 non-null     object
#  4   M           12 non-null     object
#  5   4s          12 non-null     object
#  6   6s          12 non-null     object
#  7   SR          12 non-null     object
#  8   Unnamed: 8  1 non-null      object
#  9   Unnamed: 9  0 non-null      float64
# dtypes: float64(1), object(9)
# memory usage: 2.0+ KB

# %%
xx[0].isnull().sum()
# Out:
# BATTING       10
# Unnamed: 1    10
# R             10
# B             12
# M             12
# 4s            12
# 6s            12
# SR            12
# Unnamed: 8    23
# Unnamed: 9    24
# dtype: int64

# %%
xx[0][['BATTING','R']]  #getting the data from 2 specific columns
# Out:
#                                               BATTING  \
# 0                                       Muneeba Ali †
# 1                                                 NaN
# 2                                          Iram Javed
# 3                                                 NaN
# 4                                   Bismah Maroof (c)
# 5                                                 NaN
# 6                                       Omaima Sohail
# 7                                                 NaN
# 8                                       Ayesha Naseem
# 9                                                 NaN
# 10                                         Aliya Riaz
# 11                                                NaN
# 12                                        Fatima Sana
# 13                                                NaN
# 14                                      Kainat Imtiaz
# 15                                                NaN
# ...

# %%
type(xx[0]['BATTING']) #data type of above mentioned column is series
# Out:
# pandas.core.series.Series

# %%
print(xx[0].columns)
# Out:
# Index(['BATTING', 'Unnamed: 1', 'R', 'B', 'M', '4s', '6s', 'SR', 'Unnamed: 8',
#        'Unnamed: 9'],
#       dtype='object')

# %%
xx[0]['BATTING'] #getting the data from specidic columns
# Out:
# 0                                         Muneeba Ali †
# 1                                                   NaN
# 2                                            Iram Javed
# 3                                                   NaN
# 4                                     Bismah Maroof (c)
# 5                                                   NaN
# 6                                         Omaima Sohail
# 7                                                   NaN
# 8                                         Ayesha Naseem
# 9                                                   NaN
# 10                                           Aliya Riaz
# 11                                                  NaN
# 12                                          Fatima Sana
# 13                                                  NaN
# 14                                        Kainat Imtiaz
# 15                                                  NaN
# 16                                           Diana Baig
# ...

# %%
import pandas as pd

# %%
titanic = pd.read_csv(r"D:\data ML\Datasets\amit mishra\Titanic_Data.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.describe()   #descirbe function gives description of numerical columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# #*count age 714 is showing that some value are null (891 -714 = 177)
# *mean -  average of all the datas
# *std deviation  =  deviated data from mean value
# *min =  minimum data
# *max = maximum data
# *25th 50th 75th % it will showing the data of index position of 25th percent of entire data
# ***example = data set having 1 to 12 data here min = 1, max = 12, 25th % of 12 rows will be 3rd rows data , 50% will be 6th rows data***

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# filter out all the object/categorical data type columns

# %%
titanic.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic.dtypes)  #series data types so i can filter out the data
# Out:
# pandas.core.series.Series

# %%
titanic.dtypes[titanic.dtypes == 'object']  #filterering out the columns which has object data types
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic.dtypes[titanic.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# so gettingt the complete data which has dtype == object 
titanic_str = titanic[titanic.dtypes[titanic.dtypes == 'object'].index]

# %%
titanic_str
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# seprate all the int/float datatypes
titanic[titanic.dtypes[titanic.dtypes == 'int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
titanic[titanic.dtypes[titanic.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
titanic_str.describe()  #describe the str dataset
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# by column na,e i can extract values
titanic[['Name','Age']][0:10:2]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 2                             Heikkinen, Miss. Laina  26.0
# 4                           Allen, Mr. William Henry  35.0
# 6                            McCarthy, Mr. Timothy J  54.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0

# %%
titanic[['Name','Age']][10::-2]  #extracting the data in reverse order
# Out:
#                                                  Name   Age
# 10                    Sandstrom, Miss. Marguerite Rut   4.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 6                             McCarthy, Mr. Timothy J  54.0
# 4                            Allen, Mr. William Henry  35.0
# 2                              Heikkinen, Miss. Laina  26.0
# 0                             Braund, Mr. Owen Harris  22.0

# %%
# i can also insert  the new coloumn
titanic['Raj'] = 'Sahu'

# %%
titanic.head()  # added the new column with heading - Raj and valaue = sahu
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Raj
# 0      0         A/5 21171   7.2500   NaN        S  Sahu
# 1      0          PC 17599  71.2833   C85        C  Sahu
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Sahu
# 3      0            113803  53.1000  C123        S  Sahu
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Raj             object
# dtype: object

# %%
titanic['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %% [markdown]
# ### Check the different type data or category in a dataset in both str or in int/float type data

# %%
# check the uniquness of dataset
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
# Pclass uniqueness will definne it is categorical data or not 
pd.Categorical(titanic['Pclass']) #three diffeent values in P class
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(titanic['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
pd.Categorical(titanic['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(titanic['PassengerId']) #all are different but not related
# Out:
# [1, 2, 3, 4, 5, ..., 887, 888, 889, 890, 891]
# Length: 891
# Categories (891, int64): [1, 2, 3, 4, ..., 888, 889, 890, 891]

# %%
pd.Categorical(titanic['Age'])
# Out:
# C:\Users\himan\anaconda3\lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   output = repr(obj)
# [22.0, 38.0, 26.0, 35.0, 35.0, ..., 27.0, 19.0, NaN, 26.0, 32.0]
# Length: 891
# Categories (88, float64): [0.42, 0.67, 0.75, 0.83, ..., 70.5, 71.0, 74.0, 80.0]

# %%
pd.Categorical(titanic['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
# to check the null values
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Raj              0
# dtype: int64

# %%
titanic['Age'].isnull()  #giving the true when null
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic['Age'].isnull().sum()  #total null values giving
# Out:
# 177

# %%
# filter the indexes of row where null values are
# check the data types  = series means iterable data
type(titanic['Age'].isnull() == True)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
# getting the null value indexes by using numpy 
np.where(titanic['Age'].isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
# cross check the above thing
titanic['Age'][502]
# Out:
# nan

# %% [markdown]
# ### Try to extract row number wwhere maximum farehas charged

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# for max fare when i know the max fare by above max row 
np.where(titanic['Fare'] == 512.329200)
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
# or by doing this also
titanic['Fare'] == max(titanic['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
np.where(titanic['Fare'] == max(titanic['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
# above it is showing this are the rows having maximum fare

# %%
(titanic['Fare'] == max(titanic['Fare']))[250:260]
# Out:
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# 258     True
# 259    False
# Name: Fare, dtype: bool

# %%
# extract the data from sex column
np.where(titanic['Sex'] == 'male')
# Out:
# (array([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,  21,  23,  26,
#          27,  29,  30,  33,  34,  35,  36,  37,  42,  45,  46,  48,  50,
#          51,  54,  55,  57,  59,  60,  62,  63,  64,  65,  67,  69,  70,
#          72,  73,  74,  75,  76,  77,  78,  80,  81,  83,  86,  87,  89,
#          90,  91,  92,  93,  94,  95,  96,  97,  99, 101, 102, 103, 104,
#         105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124,
#         125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144,
#         145, 146, 148, 149, 150, 152, 153, 154, 155, 157, 158, 159, 160,
#         162, 163, 164, 165, 168, 169, 170, 171, 173, 174, 175, 176, 178,
#         179, 181, 182, 183, 185, 187, 188, 189, 191, 193, 196, 197, 200,
#         201, 202, 203, 204, 206, 207, 209, 210, 212, 213, 214, 217, 219,
#         220, 221, 222, 223, 224, 225, 226, 227, 228, 231, 232, 234, 236,
#         238, 239, 242, 243, 244, 245, 248, 249, 250, 252, 253, 260, 261,
# ...

# %%
titanic['Sex'][861]
# Out:
# 'male'

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Raj'],
#       dtype='object')

# %% [markdown]
# #### Extracting the row-
# * iloc - index loaction
# * loc -  name location

# %%
titanic.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Raj                                                         Sahu
# Name: 1, dtype: object

# %%
titanic.iloc[[1,2]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Raj
# 1      0          PC 17599  71.2833   C85        C  Sahu
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Sahu

# %%
# extracting the rows where fare is maximum using iloc function
titanic.iloc[np.where(titanic['Fare'] == max(titanic['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#       Raj
# 258  Sahu
# 679  Sahu
# 737  Sahu

# %%
# extracting the name who has paid maximum fare
(titanic.iloc[np.where(titanic['Fare'] == max(titanic['Fare']))])['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# extracting the rows where fare in mimimum
np.where(titanic['Fare'] == min(titanic['Fare']))
# Out:
# (array([179, 263, 271, 277, 302, 413, 466, 481, 597, 633, 674, 732, 806,
#         815, 822], dtype=int64),)

# %%
titanic.iloc[np.where(titanic['Fare'] == min(titanic['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
# extracting the names who has paid mim fare
(titanic.iloc[np.where(titanic['Fare'] == min(titanic['Fare']))])['Name']
# Out:
# 179                 Leonard, Mr. Lionel
# 263               Harrison, Mr. William
# 271        Tornquist, Mr. William Henry
# 277         Parkes, Mr. Francis "Frank"
# 302     Johnson, Mr. William Cahoone Jr
# 413      Cunningham, Mr. Alfred Fleming
# 466               Campbell, Mr. William
# 481    Frost, Mr. Anthony Wood "Archie"
# 597                 Johnson, Mr. Alfred
# 633       Parr, Mr. William Henry Marsh
# 674          Watson, Mr. Ennis Hastings
# 732                Knight, Mr. Robert J
# 806              Andrews, Mr. Thomas Jr
# 815                    Fry, Mr. Richard
# 822     Reuchlin, Jonkheer. John George
# Name: Name, dtype: object

# %%
# survived person namee
pd.Categorical(titanic['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
titanic.info() #survived is defined by 1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Raj          891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
titanic.iloc[np.where(titanic['Survived'] == 1)][['Name','Age']]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 889                              Behr, Mr. Karl Howell  26.0
#
# [342 rows x 2 columns]

# %%
len(titanic.iloc[np.where(titanic['Survived'] == 1)][['Name','Age']])
# Out:
# 342

# %%
labels = ['a','b','c','d']
list1 = [23,13,56]
array = np.array(list1)
d = {'raj': 30, 'b': 38, 'c': 45}

# %%
# converting the data into pandas series
pd.Series(list1)
# Out:
# 0    23
# 1    13
# 2    56
# dtype: int64

# %%
# changing the index
s1 = pd.Series(list1, index = ['x','y','z'])

# %%
s1
# Out:
# x    23
# y    13
# z    56
# dtype: int64

# %%
s1[0]
# Out:
# 23

# %%
s1['x']
# Out:
# 23

# %%
array
# Out:
# array([23, 13, 56])

# %%
pd.Series(array)
# Out:
# 0    23
# 1    13
# 2    56
# dtype: int32

# %%
s2 = pd.Series(d) #here key has become the indexes

# %%
s2
# Out:
# raj    30
# b      38
# c      45
# dtype: int64

# %%
s2[0]
s2['raj']
# Out:
# 30

# %%
# creating the series
s3 = pd.Series([1,2,3,4,5,6,7], index = ['a','b','c','d','e','f','g'])

# %%
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# g    7
# dtype: int64

# %%
# creating the series
s4 = pd.Series([8,3,4,2,6,1,9], index = ['a','b','c','c','e','f','g'])

# %%
s4
# Out:
# a    8
# b    3
# c    4
# c    2
# e    6
# f    1
# g    9
# dtype: int64

# %%
s4['c']
# Out:
# c    4
# c    2
# dtype: int64

# %%
s3+s4
# Out:
# a     9.0
# b     5.0
# c     7.0
# c     5.0
# d     NaN
# e    11.0
# f     7.0
# g    16.0
# dtype: float64

# %%
s3.iloc['a']  #iloc means integer location
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [122], in <cell line: 1>()
# ----> 1 s3.iloc['a']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1517, in _iLocIndexer._getitem_axis(self, key, axis)
#    1515 key = item_from_zerodim(key)
#    1516 if not is_integer(key):
# -> 1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
#    1520 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
s4.loc['c']   #loc wil take input as str
# Out:
# c    4
# c    2
# dtype: int64

# %%
from numpy.random import randn as rn

# %%
rn(5,5)
# Out:
# array([[ 1.7582281 ,  1.63682078,  0.8500978 ,  1.99677955, -1.04304154],
#        [-1.15354926, -0.39245709, -0.48764478, -0.56343454,  0.50770701],
#        [ 1.25463738, -0.07409262, -0.53468545, -0.22138801, -0.20314937],
#        [ 1.5606442 ,  1.05723688,  1.47034268, -0.40780101,  0.91239345],
#        [ 1.17834703, -0.19107983, -0.86150206, -0.8729278 , -0.21087518]])

# %%
# converting the entire data into a dataframe using pd.DataFrame
pd.DataFrame(rn(5,5))
# Out:
#           0         1         2         3         4
# 0  1.466891 -0.258856  0.408685 -1.081927 -0.168198
# 1 -0.869802  0.968828  2.645256 -1.909696  0.528177
# 2  0.576291  0.218475  1.195706  1.348269 -0.985888
# 3  0.546904  0.894891  1.223366 -0.304807  1.345602
# 4 -0.655077 -0.204048 -1.063342  1.365644  0.738737

# %%
# also i can write my own index and own columns
df_1 =  pd.DataFrame(rn(5,5), index = ['a','b','c','d','e'], columns = [1,2,3,4,5] )

# %%
df_1
# Out:
#           1         2         3         4         5
# a -0.094902  0.371285 -0.678561  0.141141  0.118754
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394
# e -0.088971 -0.143736  0.623242  0.845827  0.558551

# %%
df_1.iloc[2]
# Out:
# 1   -0.250228
# 2   -0.297939
# 3   -1.380880
# 4   -0.421994
# 5    1.192775
# Name: c, dtype: float64

# %%
df_1.iloc[2,3]
# Out:
# -0.4219938592871216

# %%
df_1

# %%
df_1.iloc[[2,3]]
# Out:
#           1         2         3         4         5
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394

# %%
df_1.loc[['c','d','a','b']]
# Out:
#           1         2         3         4         5
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394
# a -0.094902  0.371285 -0.678561  0.141141  0.118754
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071

# %%
df_1.iloc[0:3]
# Out:
#           1         2         3         4         5
# a -0.094902  0.371285 -0.678561  0.141141  0.118754
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775

# %%
df_1.iloc[0:3:-1] #getting blank value because indexing forward and steeping backword
# Out:
# Empty DataFrame
# Columns: [1, 2, 3, 4, 5]
# Index: []

# %%
df_1.iloc[3:0:-1]
# Out:
#           1         2         3         4         5
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071

# %%
# adding the new columns
df_1['new_col'] = (df_1[1] + df_1[2])

# %%
df_1
# Out:
#           1         2         3         4         5   new_col
# a -0.094902  0.371285 -0.678561  0.141141  0.118754  0.276383
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.786377
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775 -0.548167
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -3.138313
# e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.232707

# %%
df_1['new_col1'] = (df_1[1] + df_1[2])*df_1[3]

# %%
df_1
# Out:
#           1         2         3         4         5   new_col  new_col1
# a -0.094902  0.371285 -0.678561  0.141141  0.118754  0.276383 -0.187542
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.786377 -0.042076
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775 -0.548167  0.756952
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -3.138313 -1.342712
# e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.232707 -0.145033

# %%
# inplace = True will drop the coloumn permanently
# dropping the columns - axis = 1 is column, axis = 0 row
df_1.drop('new_col', axis =1)
# Out:
#           1         2         3         4         5  new_col1
# a -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -1.342712
# e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.145033

# %%
df_1   #have not dropped the column permanently from the datafram
# Out:
#           1         2         3         4         5   new_col  new_col1
# a -0.094902  0.371285 -0.678561  0.141141  0.118754  0.276383 -0.187542
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.786377 -0.042076
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775 -0.548167  0.756952
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -3.138313 -1.342712
# e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.232707 -0.145033

# %%
df_1.drop('new_col', axis = 1, inplace = True)

# %%
df_1 #column has dropped permanently
# Out:
#           1         2         3         4         5  new_col1
# a -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -1.342712
# e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.145033

# %%
# by default drop function has axis = 0 that is row 
df_1.drop(['d','e'])
# Out:
#           1         2         3         4         5  new_col1
# a -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952

# %%
titanic['Age'].isnull().sum()
# Out:
# 177

# %%
np.where(titanic['Age'].isnull()==True)
# displaying all the rows index which has age as nun value
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
# let's check the above thing
titanic['Age'][5]
# Out:
# nan

# %%
titanic.iloc[np.where(titanic['Age'].isnull()==True)]
# it will display all the row with which has age as a null value
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# drop all the rows which has age as null value and display the rows which has age non null value

ind = np.where(titanic['Age'].isnull()==True)

# %%
titanic.drop(ind[0])   #displaying onlu non null ages rows
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_1
# Out:
#           1         2         3         4         5  new_col1
# a -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -1.342712
# e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.145033

# %%
# subset of a data frame
df_1.iloc[[0,1],[2,3]]
# Out:
#           3         4
# a -0.678561  0.141141
# b  0.053506  0.809420

# %%
df_1.loc[['a','b'],[4,5]]
# Out:
#           4         5
# a  0.141141  0.118754
# b  0.809420 -0.832071

# %%
df_1.loc[['a','b'],[4,'new_col1']]
# Out:
#           4  new_col1
# a  0.141141 -0.187542
# b  0.809420 -0.042076

# %%
df_1.iloc[0:2,4:]
# Out:
#           5  new_col1
# a  0.118754 -0.187542
# b -0.832071 -0.042076

# %%
# check the values 
df_1>0
# Out:
#        1      2      3      4      5  new_col1
# a  False   True  False   True   True     False
# b   True  False   True   True  False     False
# c  False  False  False  False   True      True
# d  False  False   True   True  False     False
# e  False  False   True   True   True     False

# %%
df_1[df_1>0]
# Out:
#           1         2         3         4         5  new_col1
# a       NaN  0.371285       NaN  0.141141  0.118754       NaN
# b  0.087701       NaN  0.053506  0.809420       NaN       NaN
# c       NaN       NaN       NaN       NaN  1.192775  0.756952
# d       NaN       NaN  0.427845  0.006369       NaN       NaN
# e       NaN       NaN  0.623242  0.845827  0.558551       NaN

# %%
# extract the data where new_col value is positive
df_1.iloc[np.where(df_1['new_col1'] > 0)]
# Out:
#           1         2        3         4         5  new_col1
# c -0.250228 -0.297939 -1.38088 -0.421994  1.192775  0.756952

# %%
# writing 2 conditions 
df_1[(df_1['new_col1'] > 0) & (df_1[5] > 0)]
# Out:
#           1         2        3         4         5  new_col1
# c -0.250228 -0.297939 -1.38088 -0.421994  1.192775  0.756952

# %%
df_1
# Out:
#           1         2         3         4         5  new_col1
# a -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# c -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952
# d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -1.342712
# e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.145033

# %%
df_1.reset_index()  #it will give the default index not permanently
# Out:
#   index         1         2         3         4         5  new_col1
# 0     a -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# 1     b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# 2     c -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952
# 3     d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -1.342712
# 4     e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.145033

# %%
df_2 =  df_1.reset_index()  # for permennt reset index use inplace = True

# %%
df_2
# Out:
#   index         1         2         3         4         5  new_col1
# 0     a -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# 1     b  0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# 2     c -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952
# 3     d -2.339341 -0.798973  0.427845  0.006369 -0.615394 -1.342712
# 4     e -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.145033

# %%
df_2.set_index('index') #i set index as a index again i can also make any column as index
# Out:
#               1         2         3         4         5  new_col1
# index
# a     -0.094902  0.371285 -0.678561  0.141141  0.118754 -0.187542
# b      0.087701 -0.874078  0.053506  0.809420 -0.832071 -0.042076
# c     -0.250228 -0.297939 -1.380880 -0.421994  1.192775  0.756952
# d     -2.339341 -0.798973  0.427845  0.006369 -0.615394 -1.342712
# e     -0.088971 -0.143736  0.623242  0.845827  0.558551 -0.145033

# %%
df_2.set_index('new_col1')  #new_col1 become the index now
# Out:
#           index         1         2         3         4         5
# new_col1
# -0.187542     a -0.094902  0.371285 -0.678561  0.141141  0.118754
# -0.042076     b  0.087701 -0.874078  0.053506  0.809420 -0.832071
#  0.756952     c -0.250228 -0.297939 -1.380880 -0.421994  1.192775
# -1.342712     d -2.339341 -0.798973  0.427845  0.006369 -0.615394
# -0.145033     e -0.088971 -0.143736  0.623242  0.845827  0.558551

# %%
dataframe = pd.DataFrame({'A':[1,2,np.nan], 'B':[5,np.nan,np.nan],'C':[1,2,3]})

# %%
dataframe
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
dataframe['States'] = "CA","NV","AZ"

# %%
dataframe
# Out:
#      A    B  C States
# 0  1.0  5.0  1     CA
# 1  2.0  NaN  2     NV
# 2  NaN  NaN  3     AZ

# %%
dataframe.set_index("States", inplace = True)

# %%
print(dataframe)
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
dataframe
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3
